# %% [markdown]
# # Dubai Housing: quick prep
# This notebook prepares data and exports an enriched CSV for the PBIX.

# %%
import pandas as pd, numpy as np
from pathlib import Path
BASE=Path('/mnt/data')
df=pd.read_csv(BASE/'housing_price_dataset.csv')
df.head()
